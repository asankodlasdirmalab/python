# %% [markdown]
# # While Loop — Tapşırıqlar
# **Mövzu:** Dərs 8 — While Loop

# %% [markdown]
# ## Tapşırıq 1 — Sadə Dövr
#
# **Şərt:** `while` loop istifadə edərək **1-dən 5-ə qədər** olan ədədləri terminala göstər
#
# **Nümunə:**
# ```
# 1
# 2
# 3
# 4
# 5
# ```

# %%
# Kodunu bura yaz

# %% [markdown]
# ## Tapşırıq 2 — Geriyə Sayma
#
# **Şərt:** `while` loop istifadə edərək **10-dan 1-ə qədər** geriyə say və hər rəqəmi göstər.
# Sonda `"Bitdi!"` sözü yazılmalıdır
#
# **Gözlənilən nəticə:**
# ```
# 10
# 9
# ...
# 1
# Bitdi!
# ```

# %%
# Kodunu bura yaz

# %% [markdown]
# ## Tapşırıq 3 — Müsbət rəqəm
#
# **Şərt:** İstifadəçidən bir ədəd daxil al.
# Əgər istifadəçi **mənfi ədəd** daxil edərsə, `"Zəhmət olmasa müsbət ədəd daxil et!"` göstər və yenidən soruş.
# Müsbət ədəd daxil edilənə qədər loop davam etsin.
# Düzgün ədəd daxil edildikdə `"Müsbət ədəd!"` yazılsın və proses dayansın.

# %%
# Tapşırıq 3 — Kodunu bura yaz

# %% [markdown]
# ## Tapşırıq 4 — Rəqəmlərin cəmi
#
# **Şərt:** İstifadəçidən tək-tək ədədlər al.
# İstifadəçi terminala `"son"` sözünü yazdıqda loop dayanmalıdır.
# Sonda daxil edilmiş bütün ədədlərin **cəmini** hesabla və terminalda göstər
#
# **Nümunə:**
# ```
# Ədəd daxil et: 10
# Ədəd daxil et: 5
# Ədəd daxil et: son
# Cəm: 15
# ```

# %%
# Kodunu bura yaz

# %% [markdown]
# ## Tapşırıq 5 — Düzgün şifrə tapmaq
#
# **Şərt:** Doğru şifrə budur: `"python123"`
# İstifadəçi şifrə daxil etməlidir
# Şifrə **yanlış** olarsa, `"Yanlış şifrə, yenidən cəhd et!"` yazılsın
# Şifrə **doğru** olarsa, `"Xoş gəldiniz!"` yazılsın və loopdan dayansın

# %%
# Kodunu bura yaz

# %% [markdown]
# ## Tapşırıq 6 — Cüt Ədədlər
#
# **Şərt:** `while` loop istifadə edərək **1-dən 20-yə qədər** olan **cüt ədədləri** terminalda göstər
#
# **Gözlənilən nəticə:**
# ```
# 2
# 4
# 6
# ...
# 20
# ```

# %%
# Kodunu bura yaz

# %% [markdown]
# ---
# ## Tapşırıq 7 — List elementləri
#
# **Şərt:** Aşağıdakı listi `while` loop ilə yoxla və hər elementi göstər
#
# ```python
# meyveler = ["alma", "armud", "banan", "gilas", "ərik"]
# ```
#
# **Gözlənilən nəticə:**
# ```
# alma
# armud
# banan
# gilas
# ərik
# ```

# %%
# Kodunu bura yaz

# %% [markdown]
# ---
# ## Tapşırıq 8 — Düzgün rəqəmi tapmaq
#
# **Şərt:** Proqramda gizli bir ədəd (məsələn, `42`) təyin et.
# İstifadəçidən ədəd təxmin etməsini istə.
# - Əgər təxmin **kiçikdirsə** → `"Daha böyük bir ədəd cəhd et!"` göstər
# - Əgər təxmin **böyükdürsə** → `"Daha kiçik bir ədəd cəhd et!"` göstər
# - Əgər **düzgündürsə** → `"Təbriklər, tapdınız!"` göstər
#
# Hər cəhddən sonra neçənci cəhd olduğunu da göstər

# %%
# Kodunu bura yaz

# %% [markdown]
# ---
# ## Tapşırıq 9 — Alış-veriş Siyahısı
#
# **Şərt:** İstifadəçi məhsul adları daxil etsin, sən onları boş bir siyahıya əlavə et.
# İstifadəçi `"son"` yazdıqda loop dayanmalıdır.
# Sonda bütün siyahını for loop enumeration ilə göstər:
#
# ```
# Alış-veriş siyahısı:
# 1. süd
# 2. çörək
# 3. yumurta
# ```

# %%
#  Kodunu bura yaz

# %% [markdown]
# ---
# ## Tapşırıq 10 — ATM Simulator
#
# **Şərt:** Sadə bir ATM proqramı yaz
# Başlanğıc balans: `500` manat.
#
# Hər dəfə istifadəçiyə menyu göstər:
# ```
# 1 — Balansa bax
# 2 — Pul çək
# 3 — Çıxış
# ```
#
# - **1 seçilərsə:** Cari balansı çap et
# - **2 seçilərsə:** İstifadəçidən məbləğ al. Əgər balans kifayət edirsə, çıxar və yeni balansı göstər. Kifayət etmirsə, `"Balansınız kifayət deyil!"` və geri qayıtmaq üçün geri yazılsın və birinci hissəyə getsin
# - **3 seçilərsə:** `"Sağolun!"` göstərib proqramı bitir
# - **Fərqli rəqəm seçilərsə:** `"Yanlış seçim, yenidən cəhd edin!"` görünsün

# %%
# Kodunu bura yaz
