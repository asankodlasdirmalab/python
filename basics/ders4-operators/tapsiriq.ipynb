# %% [markdown]
# ## Tapşırıq 1 — Dollar Çevirici
#
# İstifadəçidən alınacaq
# - pul (float)
# - valyuta (float)
#
# Nümunə cavab:
# Manat daxil edin: 34
# Valyuta daxil edin: 1.7
# Nəticə: 20.0 USD

# %% [markdown]
# ## Task 2 — Tam Ad göstər
#
# İstifadəçidən alınacaq:
# - ad (string)
# - soyad (string)
#
# Adları böyük hərflərlə yaz
#
# Nümunə cavab:
# Ad: ali
# Soyad: memmedov
#
# Nəticə:
# ALI MEMMEDOV

# %% [markdown]
# ## Tapşırıq 3 — Maaş Hesablama Sistemi
#
# İstifadəçidən alınacaq:
# - günlük maaş
# - neçə gün işlədiyi
#
# Nümunə cavab:
# Günlük maaş: 50
# İş günü: 20
# Nəticə: 1000 AZN

# %% [markdown]
# ## Tapşırıq 4 — Sosial Media Username Generator
# İstifadəçidən alınacaq:
# - ad
# - doğum ili
#
# Nümunə cavab:
# Ad: Emin
# İl: 2005
# Nəticə: emin2005

# %% [markdown]
# ## Tapşırıq 5 — Məhsul Qiymət Hesablama
# İstifadəçidən alınacaq:
# - məhsul adı
# - qiymət
# - say
#
# Ümumi məbləği hesabla və cavabı göstər
#
# Nümunə cavab
# Ümumi məbləğ: 200 manat

# %% [markdown]
# ## Task 6 — Telefondan ölkə kodunu tap
# İstifadəçidən alınacaq:
# - telefon nömrəsi
#
# Əvvəlindəki ölkə kodunu götür və göstər
#
# Nümunə cavab
# Telefon: +994504507343
# Cavab: +994
#
# Nümunə cavab
# Telefon: +15034507343
# Cavab: +1

# %% [markdown]
# ## Tapşırıq 7- login yoxlaması
#
# İstifadəçidən username və password al:
#
# - username
# - password
#
# Yoxla indiki username və şifrə doğrudursa
#
# Nəticə boolean (true yaxud false) qaytarmalıdır

# %%
duzgun_username="neriman"
duzgun_password="12345678"

# melumatlar yuxaridaki ile eyni olmalidir

# %% [markdown]
# ## Tapşırıq 8 - Tək və ya cüt ədəd yoxlaması
#
# İstifadəçidən bir rəqəm al:
# - reqem
#
# Yoxla həmin ədəd cüt ədəddir yoxsa tək
#
# Nəticə boolean (true yaxud false) qaytarmalıdır
#
# Nümunə cavab:
# reqem: 5
# cavab: False
#
# reqem: 256
# cavab: True

# %% [markdown]
# ## Tapşırıq 9 — Ən böyük ədədi tap
# İstifadəçidən üç rəqəm al:
# - reqem1
# - reqem2
# - reqem3
#
# Hansı ədəd böyükdürsə onu qaytar
#
# Nümunə cavab:
# reqem1: 5
# reqem2: 4
# reqem3: 6
# cavab: 6

# %% [markdown]
# ## Tapşırıq 10 — Aralığdakı ədəd
# İstifadəçidən 1 rəqəm al:
# - reqem
#
# Yoxla həmin ədəd 10 ilə 100-ün arasındadırsa
#
# Cavab true yaxud false qaytarmalıdır
