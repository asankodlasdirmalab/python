# %% [markdown]
# # Python Basics

# %% [markdown]
# ### Tapşırıq 1
# Aşağıdakı mətni `print()` funksiyası ilə tək sətirdə yazın, lakin terminalda hər hissə yeni sətirdən çap olunsun.
#
# **Gözlənilən cavab:**
# ```text
# Xəta: Sistem dayandı
# Status: 500
# Zaman: 2026
# ```
# **İpucu:** `\n` simvolundan istifadə edin.

# %%
# Kodunuzu burada yazın

# %% [markdown]
# ### Tapşırıq 2
# `input()` vasitəsilə istifadəçidən yaş və balans daxil etməsini istəyin. Yaşı `int`, balansı `float` tipinə çevirin və `type()` funksiyası ilə tipləri göstərin

# %%
# Kodunuzu burada yazın

# %% [markdown]
# ### Tapşırıq 3
# Verilmiş dəyişənləri `f-string` ilə göstərin
#
# ```python
# ad = "Anar"
# kurs = "Python"
# qiymet = 200
# ```
# **Gözlənilən çıxış:**
# ```text
# Tələbə: Anar
# Kurs: Python
# Qiymət: 200 AZN
# ```

# %%
ad = "Anar"
kurs = "Python"
qiymet = 200
# Kodunuzu burada yazın

# %% [markdown]
# ### Tapşırıq 4
# Verilmiş stringin başındakı və sonundakı boşluqları silin, bütün hərfləri kiçildin və tire (`-`) işarəsinə görə bölərək list halına gətirin.
#
# ```python
# data = "   CODE-LEARN-2026   "
# ```
# **İpucu:** `.strip()`, `.lower()` və `.split()` metodlarından istifadə edin.

# %%
data = "   CODE-LEARN-2026   "

# %% [markdown]
# ### Tapşırıq 5
# Verilmiş stringin (slicing vasitəsilə) ilk 4 simvolunu və son 4 simvolunu götürüb ortasında `****` olacaq şəkildə birləşdirin.
#
# ```python
# kod = "5321987654321122"
# ```
# **Gözlənilən cavab:** `5321****1122`

# %%
kod = "5321987654321122"

# %% [markdown]
# ### Tapşırıq 6
# Riyazi operatorlardan istifadə edərək:
# 1. 130-u 12-yə böldükdə alınan tam hissəni və qalığı tapın.
# 2. 5-in üstü 3-ü (qüvvətini) hesablayın.
#
# **İpucu:** `//`, `%` və `**` operatorlarından istifadə edin.

# %% [markdown]
# ### Tapşırıq 7
# Verilmiş list üzərində bu əməliyyatları edin:
# 1. Siyahının sonuna `"telefon"` əlavə edin.
# 2. İndeksi 1 olan yerə `"qulaqciq"` əlavə edin.
# 3. `"laptop"` elementini silin.
# 4. Siyahını əlifba sırası ilə sıralayın.
#
# ```python
# cihazlar = ["laptop", "ebook", "iwatch"]
# ```

# %%
cihazlar = ["laptop", "ebook", "iwatch"]

# %% [markdown]
# ### Tapşırıq 8
# Şərt operatorlarından (`if-elif-else`) istifadə edərək yoxlayın: Əgər `yas` 18 ilə 30 arasındadırsa (bərabərlik daxil) və `balans` 50-dən böyükdürsə ekrana `"Uğurlu"`, əks halda `"Uğursuz"` göstərin
#
# ```python
# yas = 22
# balans = 100
# ```

# %%
yas = 22
balans = 100
# Kodunuzu burada yazın

# %% [markdown]
# ### Tapşırıq 9
# Verilmiş şərti tək sətirdə (**One-line / Ternary condition**) yazaraq nəticəni `status` dəyişəninə mənimsədin və çap edin.
# Şərt: Əgər `xetalar` 0-a bərabərdirsə status `"OK"` olsun, əks halda `"Error"` olsun.
#
# ```python
# xetalar = 0
# ```

# %%
xetalar = 0
# Kodunuzu burada yazın

# %% [markdown]
# ### Tapşırıq 10
# `match-case` istifadə edərək `kod` yoxlayın:
# - 200 olarsa -> `"Uğurlu"`
# - 404 və ya 500 olarsa -> `"Xəta"`
# - Digər bütün hallarda (`_`) -> `"Bilinmir"` çap edin.
#
# ```python
# kod = 404
# ```

# %%
kod = 404

# %% [markdown]
# ### Tapşırıq 11
# `for` dövrü və `enumerate()` funksiyasından istifadə edərək listdəki elementləri indeksləri ilə birlikdə çap edin. Nömrələmə 1-dən başlasın.
#
# ```python
# rendler = ["qırmızı", "yaşıl", "mavi"]
# ```
# **Gözlənilən çıxış:**
# ```text
# 1 qırmızı
# 2 yaşıl
# 3 mavi
# ```

# %%
rengler = ["qırmızı", "yaşıl", "mavi"]

# %% [markdown]
# ### Tapşırıq 12
# `zip()` funksiyasından istifadə edərək iki listi paralel dövr edin və elementləri yan-yana göstərin
#
# ```python
# isler = ["A", "B", "C"]
# saatlar = [4, 8, 2]
# ```
# **Gözlənilən çıxış:**
# ```text
# A - 4
# B - 8
# C - 2
# ```

# %%
isler = ["A", "B", "C"]
saatlar = [4, 8, 2]

# %% [markdown]
# ### Tapşırıq 13
# `range(1, 15)` istifadə edərək dövr qurun. Əgər ədəd təkdirsə növbəti addıma keçsin (`continue`), əgər ədəd 10-a bərabərdirsə dövr tamamilə dayansın (`break`)

# %% [markdown]
# ### Tapşırıq 14
# `while` dövrü qurun. İstifadəçidən `input()` ilə mətn alın. İstifadəçi `"stop"` yazana qədər dövr sonsuz şəkildə davam etsin, stop yazdıqda isə `break` ilə dayansın

# %% [markdown]
# ### Tapşırıq 15
# Verilmiş təkrarlanan listi `set` tipinə çevirərək dublikatları silin, unikal elementlərin sayını (`len()`) tapın və bu set-ə `.add()` metodu ilə `"sql"` dəyərini əlavə edin.
#
# ```python
# diller = ["js", "html", "js", "css", "html"]
# ```

# %%
diller = ["js", "html", "js", "css", "html"]

# %% [markdown]
# ### Tapşırıq 16
# Verilmiş iki set üçün operatorlardan (`&`, `-`, `|`) istifadə edərək aşağıdakıları tapın və print edin:
# 1. Ortaq elementlər (Kəsişmə)
# 2. Yalnız `set_1`-də olan fərqli elementlər (Fərq)
# 3. Bütün unikal elementlər (Birləşmə)
#
# ```python
# set_1 = {"a", "b", "c"}
# set_2 = {"b", "c", "d"}
# ```

# %%
set_1 = {"a", "b", "c"}
set_2 = {"b", "c", "d"}

# %% [markdown]
# ### Tapşırıq 17
# Verilmiş `tuple` elementlərini tək sətirdə `x`, `y` və `ad` adlı dəyişənlərə mənimsədin (**Unpacking**) və göstərin.
#
# ```python
# koordinat = (10, 20, "Nöqtə_A")
# ```

# %%
koordinat = (10, 20, "Nöqtə_A")
# Kodunuzu burada yazın

# %% [markdown]
# ### Tapşırıq 18
# Bir list verilib. Hər bir elementi `ad, rol, icazeler` olaraq unpack (parse) edin. Əgər `icazeler` daxilində `"sil"` dəyəri varsa (`in` ilə yoxlayın). Varsa terminalda "silinə bilər" yazılsın
#
# ```python
# data = [
#     ("Elvin", "admin", {"oxu", "yaz", "sil"}),
#     ("Lalə", "user", {"oxu"})
# ]
# ```

# %%
data = [
    ("Elvin", "admin", {"oxu", "yaz", "sil"}),
    ("Lalə", "user", {"oxu"})
]
