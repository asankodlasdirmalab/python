# %% [markdown]
# # Python List Tapşırıqları

# %% [markdown]
# ## Tapşırıq 1
#
# Bir `meyveler` adlı list yaradın.
#
# Listin içində aşağıdakı məlumatlar olsun:
# - alma
# - armud
# - banan
#
# Daha sonra listi ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 2
#
# `reqemler` adlı list yaradın.
#
# Listin içində aşağıdakı rəqəmlər olsun:
# - 10
# - 20
# - 30
#
# Daha sonra `append()` istifadə edərək listə `40` əlavə edin.
#
# Sonda listi çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 3
#
# `adlar` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - Aysel
# - Murad
# - Kenan
#
# Index istifadə edərək:
# - ilk elementi çap edin
# - son elementi çap edin

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 4
#
# `seherler` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - Bakı
# - Gəncə
# - Şəki
#
# `insert()` istifadə edərək `Sumqayıt` sözünü 1-ci indexə əlavə edin.
#
# Sonda listi çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 5
#
# `dersler` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - Riyaziyyat
# - Fizika
# - Kimya
# - Biologiya
#
# `remove()` istifadə edərək `Kimya` elementini silin.
#
# Sonda listi çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 6
#
# `oyunlar` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - CS2
# - Minecraft
# - GTA V
# - Valorant
#
# `pop()` istifadə edərək son elementi silin.
#
# Sonda listi çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 7
#
# `heyvanlar` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - pişik
# - it
# - quş
# - balıq
#
# `pop(1)` istifadə edərək 1-ci indexdəki elementi silin.
#
# Sonda listi çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 8
#
# `ededler` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - 1
# - 2
# - 3
# - 4
# - 5
# - 6
#
# Slicing istifadə edərək:
# - ilk 3 elementi çap edin
# - son 3 elementi çap edin

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 9
#
# `rənglər` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - qırmızı
# - mavi
# - yaşıl
# - sarı
#
# Listi `[::-1]` istifadə edərək tərsinə çevirin və çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 10
#
# `eded1` adlı dəyişən yaradın və ona `5` qiymətini təyin edin. `eded2` adlı dəyişən yaradın və ona `10` qiymətini təyin edin.
#
# Arifmetik operatordan (`+`) istifadə edərək bu iki ədədi toplayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 11
#
# `qiymet` adlı dəyişənə `120`, `endirim` adlı dəyişənə isə `50` təyin edin.
#
# Çıxma operatorundan (`-`) istifadə edərək son qiyməti (qiymət - endirim) hesablayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 12
#
# `en` adlı dəyişənə `4`, `uzunluq` adlı dəyişənə `8` təyin edin.
#
# Vurma operatorundan (`*`) istifadə edərək düzbucaqlının sahəsini tapın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 13
#
# `umumi_bal` adlı dəyişənə `90`, `sual_sayi` adlı dəyişənə isə `4` təyin edin.
#
# Bölmə operatorundan (`/`) istifadə edərək hər suala düşən balı tapın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 14
#
# `gunler` adlı dəyişənə `25` təyin edin.
#
# Tam hissəli bölmə operatorundan (`//`) istifadə edərək 25 günün neçə tam həftə etdiyini tapın (bir həftə 7 gündür) və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 15
#
# `konfet` adlı dəyişənə `17`, `usaq_sayi` adlı dəyişənə isə `5` təyin edin.
#
# Qalıqlı bölmə operatorundan (`%`) istifadə edərək konfetlər bərabər bölündükdən sonra yerdə qalan konfet sayını tapın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 16
#
# `esas` adlı dəyişənə `3`, `quvvet` adlı dəyişənə `4` təyin edin.
#
# Qüvvətə yüksəltmə operatorundan (`**`) istifadə edərək 3 üstü 4-ün qiymətini hesablayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 17
#
# `sifre1` adlı dəyişənə `'1234'`, `sifre2` adlı dəyişənə isə `'1234'` təyin edin.
#
# Müqayisə operatorundan (`==`) istifadə edərək şifrələrin eyni olub-olmadığını yoxlayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 18
#
# `rol` adlı dəyişənə `'user'` təyin edin.
#
# Müqayisə operatorundan (`!=`) istifadə edərək `rol` dəyişəninin `'admin'` sözündən fərqli olub-olmadığını yoxlayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 19
#
# `istifadeci_yasi` adlı dəyişənə `16` təyin edin.
#
# Kiçikdir operatorundan (`<`) istifadə edərək yaşın 18-dən kiçik olub-olmadığını yoxlayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 20
#
# `toplanmis_bal` adlı dəyişənə `85` təyin edin.
#
# Böyükdür operatorundan (`>`) istifadə edərək balın 70-dən böyük olub-olmadığını yoxlayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 21
#
# `suret` adlı dəyişənə `100` təyin edin.
#
# Kiçikdir və ya bərabərdir operatorundan (`<=`) istifadə edərək sürətin max limit olan 100-ə bərabər və ya kiçik olmasını yoxlayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 22
#
# `temperatur` adlı dəyişənə `36.6` təyin edin.
#
# Böyükdür və ya bərabərdir operatorundan (`>=`) istifadə edərək temperaturun 36.5-dən böyük və ya bərabər olmasını yoxlayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 23
#
# `bilet_var` adlı dəyişənə `True`, `yas_catir` adlı dəyişənə isə `False` təyin edin.
#
# Məntiqi `and` operatorundan istifadə edərək hər iki şərtin eyni anda doğru olub-olmadığını yoxlayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 24
#
# `kart_var` adlı dəyişənə `False`, `naqd_pul_var` adlı dəyişənə isə `True` təyin edin.
#
# Məntiqi `or` operatorundan istifadə edərək ödəniş etmək üçün ən azı bir vasitənin olub-olmadığını yoxlayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 25
#
# `yagis_yagir` adlı dəyişənə `False` təyin edin.
#
# Məntiqi `not` operatorundan istifadə edərək bu şərtin tərsini (inkarını) tapın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 26
#
# `ad` adlı dəyişənə `'Aysel'`, `soyad` adlı dəyişənə isə `'Məmmədova'` təyin edin.
#
# `+` operatorundan istifadə edərək ad və soyadı aralarında boşluq olmaqla birləşdirin (concatenation) və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 27
#
# `metn` adlı dəyişənə `'Python'` təyin edin.
#
# Index istifadə edərək bu mətnin ilk hərfini (0-cı index) nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 28
#
# `kurs` adlı dəyişənə `'Coders'` təyin edin.
#
# Index istifadə edərək bu mətnin son hərfini (`-1`-ci index) nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 29
#
# `soz` adlı dəyişənə `'Azərbaycan'` təyin edin.
#
# Slicing (`[:]`) üsulundan istifadə edərək bu sözün ilk 3 hərfini nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 30
#
# `cumle` adlı dəyişənə `'Mən proqramlaşdırma öyrənirəm.'` təyin edin.
#
# `in` operatorundan istifadə edərək cümlədə `'proqram'` sözünün olub-olmadığını yoxlayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 31
#
# `emeliyyat` adlı dəyişənə `10 * 2 + 5` ifadəsini təyin edin.
#
# Riyazi ardıcıllığa diqqət edərək `emeliyyat` dəyişəninin qiymətini nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 32
#
# `simvol` adlı dəyişənə `'*'` təyin edin.
#
# Vurma operatorundan (`*`) istifadə edərək bu simvolu 10 dəfə təkrar nəticəni göstərin (Mətnlərin vurulması).

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 33
#
# `eded` adlı dəyişənə `14` təyin edin.
#
# Qalıqlı bölmə (`% 2 == 0`) vasitəsilə ədədin cüt olub-olmadığını yoxlayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 34
#
# `bal` adlı dəyişənə `75` təyin edin.
#
# Məntiqi operatorlardan istifadə edərək `bal`-ın 50-dən böyük VƏ 100-dən kiçik və ya bərabər olmasını (`bal > 50 and bal <= 100`) yoxlayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 35
#
# `kod` adlı dəyişənə `'ABC'` təyin edin.
#
# Slicing `[::-1]` istifadə edərək mətni tərsinə çevirin və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 36
#
# `mesaj` adlı dəyişənə `'salam'` təyin edin.
#
# Index vasitəsilə sözün ilk hərfinin `'s'` hərfinə bərabər (`==`) olub-olmadığını yoxlayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 37
#
# `say` adlı dəyişənə `45` təyin edin.
#
# Bu ədədin 5-ə tam bölündüyünü (`say % 5 == 0`) yoxlayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 38
#
# `istifadeci_adi` adlı dəyişənə `'admin'` təyin edin.
#
# Məntiqi `not` operatoru ilə istifadəçi adının `'guest'` olub-olmadığını tərsinə yoxlayın: `not istifadeci_adi == 'guest'` ifadəsinin nəticəsini göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 39
#
# `a` dəyişəninə `15`, `b` dəyişəninə `4` təyin edin.
#
# `a` ədədinin `b` ədədinə olan qalıqlı bölməsindən alınan qalığın `3`-ə bərabər olub-olmadığını yoxlayın və nəticəni göstərin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 40
#
# `boy` adlı dəyişənə `1.75` təyin edin (float data tipi).
#
# Müqayisə operatoru ilə bu boyun `1.70`-dən böyük olub-olmadığını yoxlayın və `True`/`False` nəticəsini göstərin.

# %%
# Kodunuzu buraya yazın
