# %% [markdown]
# # Python List Tapşırıqları

# %% [markdown]
# ## Tapşırıq 1
#
# Bir `meyveler` adlı list yaradın.
#
# Listin içində aşağıdakı məlumatlar olsun:
# - alma
# - armud
# - banan
#
# Daha sonra listi ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 2
#
# `reqemler` adlı list yaradın.
#
# Listin içində aşağıdakı rəqəmlər olsun:
# - 10
# - 20
# - 30
#
# Daha sonra `append()` istifadə edərək listə `40` əlavə edin.
#
# Sonda listi çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 3
#
# `adlar` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - Aysel
# - Murad
# - Kenan
#
# Index istifadə edərək:
# - ilk elementi çap edin
# - son elementi çap edin

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 4
#
# `seherler` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - Bakı
# - Gəncə
# - Şəki
#
# `insert()` istifadə edərək `Sumqayıt` sözünü 1-ci indexə əlavə edin.
#
# Sonda listi çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 5
#
# `dersler` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - Riyaziyyat
# - Fizika
# - Kimya
# - Biologiya
#
# `remove()` istifadə edərək `Kimya` elementini silin.
#
# Sonda listi çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 6
#
# `oyunlar` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - CS2
# - Minecraft
# - GTA V
# - Valorant
#
# `pop()` istifadə edərək son elementi silin.
#
# Sonda listi çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 7
#
# `heyvanlar` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - pişik
# - it
# - quş
# - balıq
#
# `pop(1)` istifadə edərək 1-ci indexdəki elementi silin.
#
# Sonda listi çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 8
#
# `ededler` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - 1
# - 2
# - 3
# - 4
# - 5
# - 6
#
# Slicing istifadə edərək:
# - ilk 3 elementi çap edin
# - son 3 elementi çap edin

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 9
#
# `rənglər` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - qırmızı
# - mavi
# - yaşıl
# - sarı
#
# Listi `[::-1]` istifadə edərək tərsinə çevirin və çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 10
#
# `massiv` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 5
# - 10
# - 15
#
# Arifmetik operatordan (`+`) istifadə edərək listin ilk iki elementini (0-cı və 1-ci index) toplayın və nəticəni ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 11
#
# `qiymetler` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 120
# - 50
#
# Çıxma operatorundan (`-`) istifadə edərək birinci elementdən ikinci elementi çıxın və nəticəni ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 12
#
# `en_hundur` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 4
# - 8
# - 12
#
# Vurma operatorundan (`*`) istifadə edərək listin bütün elementlərinin hasilini tapın və ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 13
#
# `ballar` adlı list yaradın.
#
# Listin içində aşağıdakı rəqəmlər olsun:
# - 90
# - 4
#
# Bölmə operatorundan (`/`) istifadə edərək 90-ı 4-ə bölün və alınan tam/kəsr nəticəni çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 14
#
# `olculer` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 25
# - 4
#
# Tam hissəli bölmə operatorundan (`//`) istifadə edərək 25-in 4-ə bölünməsindən alınan tam hissəni tapın və ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 15
#
# `tecrubeler` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 17
# - 5
#
# Qalıqlı bölmə operatorundan (`%`) istifadə edərək 17-nin 5-ə bölünməsindən alınan qalığı tapın və ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 16
#
# `quvvet` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 3
# - 4
#
# Qüvvətə yüksəltmə operatorundan (`**`) istifadə edərək 3 üstü 4-ün qiymətini hesablayın və ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 17
#
# `test_siyahisi` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 50
# - 50
#
# Müqayisə operatorundan (`==`) istifadə edərək bu iki elementin bir-birinə bərabər olub-olmadığını yoxlayın və `True` və ya `False` cavabını ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 18
#
# `kodlar` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 'admin'
# - 'user'
#
# Müqayisə operatorundan (`!=`) istifadə edərək bu iki mətnin bir-birindən fərqli olub-olmadığını yoxlayın və ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 19
#
# `yaslar` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 18
# - 25
#
# Kiçikdir operatorundan (`<`) istifadə edərək ilk elementin ikinci elementdən kiçik olub-olmadığını yoxlayın və nəticəni ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 20
#
# `ballar` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 85
# - 70
#
# Böyükdür operatorundan (`>`) istifadə edərək ilk elementin ikinci elementdən böyük olub-olmadığını yoxlayın və nəticəni çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 21
#
# `limitler` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 100
# - 100
#
# Kiçikdir və ya bərabərdir operatorundan (`<=`) istifadə edərək ilk elementin ikincidən kiçik və ya bərabər olmasını yoxlayın və nəticəni ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 22
#
# `dereceler` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 36.6
# - 36.5
#
# Böyükdür və ya bərabərdir operatorundan (`>=`) istifadə edərək ilk elementin ikincidən böyük və ya bərabər olmasını yoxlayın və nəticəni ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 23
#
# `mentiq` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - True
# - False
#
# Məntiqi `and` operatorundan istifadə edərək listin birinci və ikinci elementini müqayisə edin və nəticəni ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 24
#
# `durumlar` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - False
# - True
#
# Məntiqi `or` operatorundan istifadə edərək listin birinci və ikinci elementini müqayisə edin və nəticəni ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 25
#
# `cavablar` adlı list yaradın.
#
# Listin içində aşağıdakı element olsun:
# - False
#
# Məntiqi `not` operatorundan istifadə edərək listin ilk elementinin tərsini tapın və ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 26
#
# `ededler` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 10
# - 5
# - 2
#
# Listin ilk elementini, digər iki elementin hasilinə (`*`) bərabər olub-olmadığını (`==`) yoxlayın və nəticəni ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 27
#
# `metnler` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 'Python'
# - 'Java'
#
# `len()` funksiyasından istifadə edərək hər iki sözün uzunluğunu tapın və birinci sözün uzunluğunun ikincidən böyük (`>`) olub-olmadığını ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 28
#
# Bir `kvadratlar` adlı boş list yaradın.
#
# `append()` metodundan istifadə edərək ardıcıl olaraq, 5-in kvadratını (`5**2`) və 6-nın kvadratını (`6**2`) listə əlavə edin. Sonda listi çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 29
#
# `qiymetlendirme` adlı list yaradın.
#
# Listin içində aşağıdakı elementlər olsun:
# - 45
# - 60
#
# İlk elementin 50-dən böyük olması şərti ilə, ikinci elementin də 50-dən böyük olması şərtini `and` operatoru ilə birləşdirib yoxlayın və nəticəni ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 30
#
# `istifadeciler` adlı list yaradın.
#
# Listin içində aşağıdakılar olsun:
# - 'Anar'
# - 'Elvin'
#
# `in` operatorundan istifadə edərək 'Anar' sözünün bu listdə olub-olmadığını (`True`/`False`) ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 31
#
# `reqem_listi` adlı list yaradın:
# - 15
# - 30
# - 45
#
# Listin sonuncu elementinin 3-ə və 5-ə tam bölündüyünü (`% 3 == 0 and % 5 == 0`) yoxlayın və nəticəni ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 32
#
# `fennler` adlı list yaradın:
# - 'Tarix'
# - 'Cografiya'
#
# `insert()` metodundan istifadə edərək 0-cı indexə 'Kimya' fənnini əlavə edin və sonda listin yeni 1-ci indexindəki elementi ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 33
#
# `tek_cut` adlı list yaradın:
# - 14
#
# Listin yeganə elementinin cüt ədəd olub-olmadığını qalıqlı bölmə (`% 2 == 0`) vasitəsilə yoxlayın və ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 34
#
# `faizler` adlı list yaradın:
# - 75
# - 120
#
# Listin hər hansı bir elementinin 100-dən böyük (`>`) olub-olmadığını `or` operatoru ilə yoxlayın və ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 35
#
# `test_list` adlı list yaradın:
# - 10
# - 20
# - 30
# - 40
#
# Slicing (`[1:3]`) istifadə edərək ortadakı iki elementi çıxarın və bu alt-listin ilk elementinin 20-yə bərabər olub-olmadığını yoxlayın.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 36
#
# `sozler` adlı list yaradın:
# - 'alma'
# - 'kitab'
#
# Listin birinci elementinin 'a' hərfi ilə başlayıb-başlamadığını yoxlamaq üçün index istifadə edin (məsələn, sözün 0-cı hərfi `== 'a'`) və nəticəni ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 37
#
# `data` adlı list yaradın:
# - 50
# - 100
# - 150
#
# `pop(0)` vasitəsilə ilk elementi silin. Daha sonra yeni listin ilk elementinin (yəni əvvəlki 100-ün) 100-ə bərabər olub-olmadığını müqayisə edin və çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 38
#
# `deyerler` adlı list yaradın:
# - True
# - True
#
# Hər iki elementin `True` olub-olmadığını `and` operatoru ilə yoxlayın. Sonra `not` operatoru ilə bu yekun nəticəni tərsinə çevirib ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 39
#
# `siyahi_A` və `siyahi_B` adlı iki fərqli list yaradın:
# - `siyahi_A` içində `[1, 2]` olsun
# - `siyahi_B` içində `[3, 4]` olsun
#
# `+` operatorundan istifadə edərək bu iki listi birləşdirin və alınan yeni geniş listi ekrana çap edin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ## Tapşırıq 40
#
# `son_test` adlı list yaradın:
# - 9
# - 3
#
# İlk elementin ikinci elementə bölünməsindən alınan tam hissənin (`//`) 3-ə bərabər (`==`) olub-olmadığını yoxlayın və nəticəni (`True`/`False`) ekrana çap edin.

# %%
# Kodunuzu buraya yazın
